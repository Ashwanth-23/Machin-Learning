# %%
import pandas as pd
import numpy as np

# %%
path="/content/drive/MyDrive/Colab Notebooks/Data /churn_dataset (1).csv"

# %%
df= pd.read_csv(path)
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
#Getting columns with datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ### Converting the TotalChargers Columns into Float by using astype

# %%
df['TotalCharges'] = df['TotalCharges'].replace(' ', np.nan)

# %%
df['TotalCharges']=df['TotalCharges'].astype('float')

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# ### Ckecking the Duplicate

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Getting number of (rows , columns)
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ### Checking the Null Values

# %%
#checking the Null
df.isna().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df['TotalCharges']
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %% [markdown]
# ### Dropng the NANs From above DataFrame.

# %%
df=df.dropna()

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# ### Univariate Analysis
# Non-Viz
# Min
# Max
# Central tendency
# Dispersion
#
# Viz
# plot of Distribution - Distribution
# plot of BoxPlot - Outliers

# %%
df.select_dtypes(exclude="object").columns
# Out:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges'], dtype='object')

# %% [markdown]
# ### Analysis on SeciorCitizen Feature

# %%
#Non Visulization analysis
print(df["SeniorCitizen"].min())
print(df["SeniorCitizen"].max())
print(df["SeniorCitizen"].mean())
print(df["SeniorCitizen"].median())
print(df["SeniorCitizen"].std())
# Out:
# 0
# 1
# 0.16240045506257111
# 0.0
# 0.3688439967571051

# %% [markdown]
# From above SeniorCitizen column Look like mean and median are colse, there may be are very few or no outlier--.

# %%
# Distribution Of Seniorcitizen Feature using kde plot
df['SeniorCitizen'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
#checking Seniorcitizen Feature using  Boxplot
df["SeniorCitizen"].plot(kind="box")
# Out:
# <Axes: >

# %%
df["SeniorCitizen"].value_counts().plot(kind="box")
# Out:
# <Axes: >

# %% [markdown]
#  There is one outlier in the SeniorCitizen feature. But it is not outlier most of the values for senior citizen having 1.

# %%
#checking for normal distribution using QQ-plot
from scipy import stats
import matplotlib.pyplot as plt
stats.probplot(df['SeniorCitizen'],dist='norm',plot=plt)
plt.grid()

# %% [markdown]
#  By the above QQ-plot,the SeniorCitizen feature is not normally distributed.

# %% [markdown]
# ### Analysis on Tenure Feature

# %%
#Non Visulization analysis
print(df["tenure"].min())
print(df["tenure"].max())
print(df["tenure"].mean())
print(df["tenure"].median())
print(df["tenure"].std())
# Out:
# 1
# 72
# 32.421786120591584
# 29.0
# 24.545259709263256

# %%
# Distribution Of tenure Feature using kde plot
df['tenure'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
#checking tenure Feature using  Boxplot
df["tenure"].plot(kind="box")
# Out:
# <Axes: >

# %% [markdown]
# There is no outliers in the tenure feature

# %%
#checking for normal distribution using QQ-plot
stats.probplot(df['tenure'],dist='norm',plot=plt)
plt.grid()

# %% [markdown]
#  By the above QQ-plot,the tenure feature is not normally distributed.

# %% [markdown]
# ### Analysis on MonthlyCharges Feature

# %%
#Non Visulization analysis
print(df["MonthlyCharges"].min())
print(df["MonthlyCharges"].max())
print(df["MonthlyCharges"].mean())
print(df["MonthlyCharges"].median())
print(df["MonthlyCharges"].std())
# Out:
# 18.25
# 118.75
# 64.79820819112628
# 70.35
# 30.085973884049842

# %%
# Distribution Of MonthlyCharges Feature using kde plot
df['MonthlyCharges'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
#checking MonthlyCharges Feature using  Boxplot
df['MonthlyCharges'].plot(kind="box")
# Out:
# <Axes: >

# %% [markdown]
#  There is no outliers in the tenure feature

# %%
#checking for normal distribution using QQ-plot
stats.probplot(df['MonthlyCharges'],dist='norm',plot=plt)
plt.grid()

# %% [markdown]
# MonthlyCharges column does not follows normal distribution

# %% [markdown]
# ### Analysis on TotalCharges Feature

# %%
#Non Visulization analysis
print(df["TotalCharges"].min())
print(df["TotalCharges"].max())
print(df["TotalCharges"].mean())
print(df["TotalCharges"].median())
print(df["TotalCharges"].std())
# Out:
# 18.8
# 8684.8
# 2283.300440841866
# 1397.475
# 2266.771361883145

# %%
# Distribution Of TotalCharges Feature using kde plot
df['TotalCharges'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
#checking TotalCharges Feature using  Boxplot
df['TotalCharges'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
#  TotalCharges column does not having any outliers

# %%
#checking for normal distribution using QQ-plot
stats.probplot(df['TotalCharges'],dist='norm',plot=plt)
plt.grid()

# %% [markdown]
#  TotalCharges column does not follows normal distribution. And mean,median having difference in large number.

# %%
def uni_variate(df,column):
    if df[column].dtype in ["O"]:
        print("Feature =",column)
        print("mode:",df[column].mode())
        print("------------------------------------------------")
        print("Value_counts:\n",df[column].value_counts())
        print(df[column].value_counts().plot(kind = 'bar'),plt.show())

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['customerID', 'gender', 'Partner', 'Dependents', 'PhoneService',
#        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'Contract', 'PaperlessBilling', 'PaymentMethod', 'Churn'],
#       dtype='object')

# %% [markdown]
# ### Analysis on Gender Feature

# %%
uni_variate(df,"gender")
# Out:
# Feature = gender
# mode: 0    Male
# Name: gender, dtype: object
# ------------------------------------------------
# Value_counts:
#  Male      3549
# Female    3483
# Name: gender, dtype: int64
# Axes(0.125,0.11;0.775x0.77) None

# %% [markdown]
# Insight : Male Persons has 1% greater than Female in the data, Male are 3555 and females are 3488

# %% [markdown]
# ### Analysis on Partner Feature

# %%
uni_variate(df,"Partner")
# Out:
# Feature = Partner
# mode: 0    No
# Name: Partner, dtype: object
# ------------------------------------------------
# Value_counts:
#  No     3639
# Yes    3393
# Name: Partner, dtype: int64
# Axes(0.125,0.11;0.775x0.77) None

# %% [markdown]
# ### Analysis on Dependents

# %%
uni_variate(df,"Dependents")
# Out:
# Feature = Dependents
# mode: 0    No
# Name: Dependents, dtype: object
# ------------------------------------------------
# Value_counts:
#  No     4933
# Yes    2099
# Name: Dependents, dtype: int64
# Axes(0.125,0.11;0.775x0.77) None

# %% [markdown]
#  From above plot Dependent customer are less ..

# %% [markdown]
# ### Analysis on PhoneServices

# %%
uni_variate(df,"PhoneService")
# Out:
# Feature = PhoneService
# mode: 0    Yes
# Name: PhoneService, dtype: object
# ------------------------------------------------
# Value_counts:
#  Yes    6352
# No      680
# Name: PhoneService, dtype: int64
# Axes(0.125,0.11;0.775x0.77) None

# %% [markdown]
# From the above plot Phoneservices high

# %% [markdown]
# ### Analysis on MultipleLines

# %%
  uni_variate(df,"MultipleLines")
# Out:
# Feature = MultipleLines
# mode: 0    No
# Name: MultipleLines, dtype: object
# ------------------------------------------------
# Value_counts:
#  No                  3385
# Yes                 2967
# No phone service     680
# Name: MultipleLines, dtype: int64
# Axes(0.125,0.11;0.775x0.77) None

# %% [markdown]
# From the above plot most the dosn't have multipleline connection

# %% [markdown]
# ### Analysis on InternetService

# %%
uni_variate(df,"InternetService")
# Out:
# Feature = InternetService
# mode: 0    Fiber optic
# Name: InternetService, dtype: object
# ------------------------------------------------
# Value_counts:
#  Fiber optic    3096
# DSL            2416
# No             1520
# Name: InternetService, dtype: int64
# Axes(0.125,0.11;0.775x0.77) None

# %% [markdown]
#  From the plot more cudtomer used Fiber optic internet services

# %% [markdown]
# ### Analysis on OnlineSecurity

# %%
uni_variate(df,"OnlineSecurity")
# Out:
# Feature = OnlineSecurity
# mode: 0    No
# Name: OnlineSecurity, dtype: object
# ------------------------------------------------
# Value_counts:
#  No                     3497
# Yes                    2015
# No internet service    1520
# Name: OnlineSecurity, dtype: int64
# Axes(0.125,0.11;0.775x0.77) None

# %% [markdown]
# Most of the customer has no online Security

# %% [markdown]
# ### Analysis on Online Backup

# %%
uni_variate(df,"OnlineBackup")
# Out:
# Feature = OnlineBackup
# mode: 0    No
# Name: OnlineBackup, dtype: object
# ------------------------------------------------
# Value_counts:
#  No                     3087
# Yes                    2425
# No internet service    1520
# Name: OnlineBackup, dtype: int64
# Axes(0.125,0.11;0.775x0.77) None

# %% [markdown]
# Most customer no online Backup

# %% [markdown]
# ### Analysis on Device Protection

# %%
uni_variate(df,"DeviceProtection")
# Out:
# Feature = DeviceProtection
# mode: 0    No
# Name: DeviceProtection, dtype: object
# ------------------------------------------------
# Value_counts:
#  No                     3094
# Yes                    2418
# No internet service    1520
# Name: DeviceProtection, dtype: int64
# Axes(0.125,0.11;0.775x0.77) None

# %% [markdown]
# Most of the customers has no Device Protection

# %% [markdown]
# ### Analysis on Technical support

# %%
uni_variate(df,"TechSupport")
# Out:
# Feature = TechSupport
# mode: 0    No
# Name: TechSupport, dtype: object
# ------------------------------------------------
# Value_counts:
#  No                     3472
# Yes                    2040
# No internet service    1520
# Name: TechSupport, dtype: int64
# Axes(0.125,0.11;0.775x0.77) None

# %% [markdown]
# Most of the customer has no techincal support

# %% [markdown]
# ### Analysis on Streaming Tv

# %%
uni_variate(df,"StreamingTV")
# Out:
# Feature = StreamingTV
# mode: 0    No
# Name: StreamingTV, dtype: object
# ------------------------------------------------
# Value_counts:
#  No                     2809
# Yes                    2703
# No internet service    1520
# Name: StreamingTV, dtype: int64
# Axes(0.125,0.11;0.775x0.77) None

# %% [markdown]
# ### Analysis on Streaming Movies

# %%
uni_variate(df,"StreamingMovies")
# Out:
# Feature = StreamingMovies
# mode: 0    No
# Name: StreamingMovies, dtype: object
# ------------------------------------------------
# Value_counts:
#  No                     2781
# Yes                    2731
# No internet service    1520
# Name: StreamingMovies, dtype: int64
# Axes(0.125,0.11;0.775x0.77) None

# %% [markdown]
# ### Analysis on Contract

# %%
uni_variate(df,"Contract")
# Out:
# Feature = Contract
# mode: 0    Month-to-month
# Name: Contract, dtype: object
# ------------------------------------------------
# Value_counts:
#  Month-to-month    3875
# Two year          1685
# One year          1472
# Name: Contract, dtype: int64
# Axes(0.125,0.11;0.775x0.77) None

# %% [markdown]
# Most of the customer perfer to month to month service

# %% [markdown]
# ### Analysis on PaperlessBilling

# %%
uni_variate(df,"PaperlessBilling")
# Out:
# Feature = PaperlessBilling
# mode: 0    Yes
# Name: PaperlessBilling, dtype: object
# ------------------------------------------------
# Value_counts:
#  Yes    4168
# No     2864
# Name: PaperlessBilling, dtype: int64
# Axes(0.125,0.11;0.775x0.77) None

# %% [markdown]
# More Customer are used by paperlessBilling

# %% [markdown]
# ### Analysis on Payment Method

# %%
uni_variate(df,"PaymentMethod")
# Out:
# Feature = PaymentMethod
# mode: 0    Electronic check
# Name: PaymentMethod, dtype: object
# ------------------------------------------------
# Value_counts:
#  Electronic check             2365
# Mailed check                 1604
# Bank transfer (automatic)    1542
# Credit card (automatic)      1521
# Name: PaymentMethod, dtype: int64
# Axes(0.125,0.11;0.775x0.77) None

# %% [markdown]
#  Most of the customer are used to payment as Electronic check

# %% [markdown]
# ### Analysis on Churn

# %%
uni_variate(df,"Churn")
# Out:
# Feature = Churn
# mode: 0    No
# Name: Churn, dtype: object
# ------------------------------------------------
# Value_counts:
#  No     5163
# Yes    1869
# Name: Churn, dtype: int64
# Axes(0.125,0.11;0.775x0.77) None

# %% [markdown]
# From the above graph , in Chrun Feature most of the customer need to continue with same telecommunication only

# %% [markdown]
# ### Bi-variate Analysis

# %%
# Writing function for Bi variate analysis Vizualization
import seaborn as sns
def bi_viz(x):
    if x.dtype==object :
        pd.crosstab(df["Churn"],x).plot(kind="bar",width=0.8,stacked=True)
        plt.show()

# %% [markdown]
# ### Analysis the Relationship B/w Gender and Churn Feature

# %%
bi_viz(df["gender"])

# %% [markdown]
# -There is no relationship between gender and churn features.

# %% [markdown]
# ### Analysis the Relationship B/w Partner V/s Churn

# %%
bi_viz(df["Partner"])

# %% [markdown]
#  There is no relationship between Partner and Churn features.

# %% [markdown]
# ### Analysis the Relationship B/w Dependents and Churn

# %%
bi_viz(df["Dependents"])

# %% [markdown]
#  There is no relationship between Dependents and Churn

# %% [markdown]
# ### Analysis the Relationship B/w PhoneService and Churn

# %%
bi_viz(df["PhoneService"])

# %% [markdown]
#  There is no realtionship between PhoneService and Churn features.

# %% [markdown]
# #### Analysis the Relationship B/w MultipleLines and Churn

# %%
bi_viz(df["MultipleLines"])

# %% [markdown]
# There is no relationship between MultiLines and churn features.

# %% [markdown]
# ### Analysis the Relationship B/w InternetService and Churn

# %%
bi_viz(df["InternetService"])

# %% [markdown]
# The type of internet service a customer has subscribed to can impact churn. Customers with slow or unreliable internet connections may be more likely to churn compared to those with high-speed and reliable connections.

# %% [markdown]
# #### Analysis the Relationship B/w OnlineSecurity and Churn

# %%
bi_viz(df["OnlineSecurity"])

# %% [markdown]
# - The availability of services like online security  can influence churn. Customers who encounter frequent technical issues or feel insecure about their online activities may be more likely to churn if these services are not provided.

# %% [markdown]
# ### Analysis the Relationship B/w OnlineBackup and Churn

# %%
bi_viz(df["OnlineBackup"])

# %% [markdown]
#  - There is no realtionship between Onlinebackup and Churn features.

# %% [markdown]
# ### Analysis the Relationship B/w DeviceProtection and Churn

# %%
bi_viz(df["DeviceProtection"])

# %% [markdown]
#  - There is no realtionship between DeviceProtection and churn features.

# %% [markdown]
# ### Analysis the Relationship B/w TechSupport and Churn

# %%
bi_viz(df["TechSupport"])

# %% [markdown]
# - The availability of services like tech support can influence churn. Customers who encounter frequent technical issues or feel insecure about their online activities may be more likely to churn if these services are not provided.

# %% [markdown]
# ### Analysis the Relationship B/w StreamingTV and Churn

# %%
bi_viz(df["StreamingTV"])

# %% [markdown]
#  - There is no realtionship between StreamingTV and churn features.

# %% [markdown]
# ### Analysis the Relationship B/w StreamingMovies and Churn

# %%
bi_viz(df["StreamingMovies"])

# %% [markdown]
#  - There is no realtionship between StreamingMovies and churn features.

# %% [markdown]
# ### Analysis the Relationship B/w Contract and Churn

# %%
bi_viz(df["Contract"])

# %% [markdown]
#  - The type of contract a customer has can have a significant impact on churn. Customers on month-to-month contracts tend to have higher churn rates compared to those on longer-term contracts, such as one or two-year contracts. This is because customers with shorter contracts have more flexibility to switch providers.

# %% [markdown]
# ### Analysis the Relationship B/w PaperlessBilling and Churn

# %%
bi_viz(df["PaperlessBilling"])

# %% [markdown]
# - There is no realtionship between PaperlessBilling and Churn features.

# %% [markdown]
# ### Analysis the Relationship B/w PaymentMethod and Churn

# %%
bi_viz(df["PaymentMethod"])

# %% [markdown]
#  - The payment method chosen by customers can have an impact on churn. customers using automatic payments or those with  annual payments may have lower churn rates compared to customers who manually pay each month.

# %% [markdown]
# ### Analysis the replationship B/w SeniorCitizen v/s churn

# %%
plt.box(df, x = "Churn", y ="SeniorCitizen" )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-fdde715393bc> in <cell line: 1>()
# ----> 1 plt.box(df, x = "Churn", y ="SeniorCitizen" )
#
# TypeError: box() got an unexpected keyword argument 'x'

# %%
sns.boxplot(x="SeniorCitizen",y="Churn",data=df)
# Out:
# <Axes: xlabel='SeniorCitizen', ylabel='Churn'>

# %% [markdown]
#  From Above Graph we have observed that only few SeniorCitizen are ready to Churn

# %% [markdown]
# ### Analysis the Relationship B/w tenure and Churn

# %%
sns.boxplot(y="tenure",x="Churn",data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='tenure'>

# %% [markdown]
#   There is no relationship between tenure and Churn

# %% [markdown]
# ### Analysis the Relationship B/w MonthlyCharges and Churn

# %%
sns.boxplot(y="MonthlyCharges",x="Churn",data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='MonthlyCharges'>

# %% [markdown]
#  - Higher monthly charges can be a contributing factor to churn. Customers who perceive the service as expensive or are not satisfied with the value they receive may be more likely to churn.

# %% [markdown]
# ### Analysis the Relationship B/w TotalCharges and Churn

# %%
sns.boxplot(y="TotalCharges",x="Churn",data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='TotalCharges'>

# %% [markdown]
#  - Higher total charges can be a contributing factor to churn. Customers who perceive the service as expensive or are not satisfied with the value they receive may be more likely to churn.

# %% [markdown]
# ### Insights

# %% [markdown]
# . Customers subscribed to specific services, such as online security, online backup, device protection, and tech support, may be   more likely to churn. The telecom company should investigate the quality, availability, and value proposition of these services to improve customer retention.
# . The contract type, payment method, and paperless billing options may influence customer churn. Consider offering flexible       contract options, convenient payment methods, and incentives for paperless billing to encourage customer loyalty.
# . High monthly charges and total charges may contribute to customer churn. Evaluate pricing strategies and ensure that customers   perceive the value of the services they receive.
# . Demographic factors may play a role in churn. Tailor marketing campaigns and customer retention strategies based on gender,     age range, and family status.

# %% [markdown]
# ### Conclusions

# %% [markdown]
# - Conduct customer surveys or interviews to gain qualitative insights into the reasons behind churn and gather feedback on       service quality and customer experience.
# - Implement proactive customer retention measures, such as personalized offers, loyalty programs, or customer service e           enhancements, for customers identified as high-risk for churn.
# - Regularly review and update service offerings to align with customer needs and preferences, considering market trends and       competitors.
# - Invest in improving customer support channels, ensuring prompt and effective resolutions to customer issues and concerns.
# - Develop data-driven churn prediction models to identify at-risk customers and implement targeted interventions to reduce         churn.

# %% [markdown]
# ## Sprint - 2

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
import sklearn

# %% [markdown]
# #### Identifying the inputs (X) and output (y)

# %%
y = df["Churn"]

X = df[['gender', 'SeniorCitizen', 'Partner', 'Dependents','tenure', 'PhoneService', 'MultipleLines', 'InternetService','OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport','StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling','PaymentMethod', 'MonthlyCharges', 'TotalCharges']]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.75, random_state=100)

X_train.head()
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 5523  Female              0     Yes         No       7          Yes
# 1676  Female              0      No         No       4          Yes
# 511     Male              0      No         No      61          Yes
# 1595    Male              1      No         No       2          Yes
# 3329  Female              0     Yes         No      18          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 5523            No     Fiber optic             No           No
# 1676           Yes     Fiber optic            Yes           No
# 511            Yes     Fiber optic            Yes           No
# 1595            No     Fiber optic             No          Yes
# 3329            No             DSL             No           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 5523               No          No          No              No  Month-to-month
# ...

# %%
print(X_train.shape, y_train.shape)

print(X_test.shape, y_test.shape)
# Out:
# (5274, 19) (5274,)
# (1758, 19) (1758,)

# %% [markdown]
# #### Separating Categorical and Numerical Columns:

# %%
X_train.head()
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 5523  Female              0     Yes         No       7          Yes
# 1676  Female              0      No         No       4          Yes
# 511     Male              0      No         No      61          Yes
# 1595    Male              1      No         No       2          Yes
# 3329  Female              0     Yes         No      18          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 5523            No     Fiber optic             No           No
# 1676           Yes     Fiber optic            Yes           No
# 511            Yes     Fiber optic            Yes           No
# 1595            No     Fiber optic             No          Yes
# 3329            No             DSL             No           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 5523               No          No          No              No  Month-to-month
# ...

# %%
X_train.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# dtype: object

# %%
X_train_cat = X_train.select_dtypes(include=['object'])

X_train_cat.head()
# Out:
#       gender Partner Dependents PhoneService MultipleLines InternetService  \
# 5523  Female     Yes         No          Yes            No     Fiber optic
# 1676  Female      No         No          Yes           Yes     Fiber optic
# 511     Male      No         No          Yes           Yes     Fiber optic
# 1595    Male      No         No          Yes            No     Fiber optic
# 3329  Female     Yes         No          Yes            No             DSL
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 5523             No           No               No          No          No
# 1676            Yes           No               No          No          No
# 511             Yes           No              Yes          No         Yes
# 1595             No          Yes               No          No          No
# 3329             No           No               No         Yes          No
#
#      StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
X_train_num = X_train.select_dtypes(include=['int64', 'float64'])

X_train_num.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 5523              0       7           69.20        477.55
# 1676              0       4           80.15        319.85
# 511               0      61          106.45       6300.15
# 1595              1       2           74.70        165.40
# 3329              0      18           50.30        908.75

# %% [markdown]
# #### Scaling the Numerical Features

# %%
X_train_num.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 5523              0       7           69.20        477.55
# 1676              0       4           80.15        319.85
# 511               0      61          106.45       6300.15
# 1595              1       2           74.70        165.40
# 3329              0      18           50.30        908.75

# %%
# scaling the numerical features
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# column names are (annoyingly) lost after Scaling
# (i.e. the dataframe is converted to a numpy ndarray)

X_train_num_rescaled = pd.DataFrame(scaler.fit_transform(X_train_num),
                                    columns = X_train_num.columns,
                                    index = X_train_num.index)

X_train_num_rescaled.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# 5523      -0.438945 -1.035648        0.151080     -0.795902
# 1676      -0.438945 -1.157923        0.514997     -0.865409
# 511       -0.438945  1.165295        1.389062      1.770434
# 1595       2.278188 -1.239439        0.333869     -0.933484
# 3329      -0.438945 -0.587308       -0.477051     -0.605849

# %%
X_train_num.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    5274.000000  5274.000000     5274.000000   5274.000000
# mean        0.161547    32.409556       64.654124   2283.323341
# std         0.368070    24.537263       30.092133   2269.052626
# min         0.000000     1.000000       18.250000     18.850000
# 25%         0.000000     9.000000       35.500000    395.725000
# 50%         0.000000    29.000000       70.250000   1394.325000
# 75%         0.000000    55.000000       89.850000   3778.075000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
print("Number of Numerical Features:", scaler.n_features_in_)
print("Mean of each column:", scaler.mean_)
print("Std of each column:", np.sqrt(scaler.var_))
# Out:
# Number of Numerical Features: 4
# Mean of each column: [1.61547213e-01 3.24095563e+01 6.46541240e+01 2.28332334e+03]
# Std of each column: [3.68034931e-01 2.45349362e+01 3.00892798e+01 2.26883750e+03]

# %%
#### Applying OneHotEncoding on Categorical Columns

# %%
X_train_cat.head()
# Out:
#       gender Partner Dependents PhoneService MultipleLines InternetService  \
# 5523  Female     Yes         No          Yes            No     Fiber optic
# 1676  Female      No         No          Yes           Yes     Fiber optic
# 511     Male      No         No          Yes           Yes     Fiber optic
# 1595    Male      No         No          Yes            No     Fiber optic
# 3329  Female     Yes         No          Yes            No             DSL
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 5523             No           No               No          No          No
# 1676            Yes           No               No          No          No
# 511             Yes           No              Yes          No         Yes
# 1595             No          Yes               No          No          No
# 3329             No           No               No         Yes          No
#
#      StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
X_train_cat['gender'].value_counts(normalize=True)
# Out:
# Male      0.505878
# Female    0.494122
# Name: gender, dtype: float64

# %%
X_train_cat['Partner'].value_counts(normalize=True)
# Out:
# No     0.521426
# Yes    0.478574
# Name: Partner, dtype: float64

# %%
X_train_cat['Dependents'].value_counts(normalize=True)
# Out:
# No     0.703641
# Yes    0.296359
# Name: Dependents, dtype: float64

# %%
# OneHotEncoding the categorical features

from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(drop='first', sparse=False)

# column names are (annoyingly) lost after OneHotEncoding
# (i.e. the dataframe is converted to a numpy ndarray)

X_train_cat_ohe = pd.DataFrame(encoder.fit_transform(X_train_cat),
                               columns=encoder.get_feature_names_out(X_train_cat.columns),
                               index = X_train_cat.index)

X_train_cat_ohe.head()
# Out:
#       gender_Male  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 5523          0.0          1.0             0.0               1.0
# 1676          0.0          0.0             0.0               1.0
# 511           1.0          0.0             0.0               1.0
# 1595          1.0          0.0             0.0               1.0
# 3329          0.0          1.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  \
# 5523                             0.0                0.0
# 1676                             0.0                1.0
# 511                              0.0                1.0
# 1595                             0.0                0.0
# 3329                             0.0                0.0
#
#       InternetService_Fiber optic  InternetService_No  \
# 5523                          1.0                 0.0
# 1676                          1.0                 0.0
# 511                           1.0                 0.0
# ...

# %%
#### Concatinating the Encoded Categorical Features and Rescaled Numerical Features:

# %%
X_train_transformed = pd.concat([X_train_num_rescaled, X_train_cat_ohe], axis=1)

X_train_transformed.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 5523      -0.438945 -1.035648        0.151080     -0.795902          0.0
# 1676      -0.438945 -1.157923        0.514997     -0.865409          0.0
# 511       -0.438945  1.165295        1.389062      1.770434          1.0
# 1595       2.278188 -1.239439        0.333869     -0.933484          1.0
# 3329      -0.438945 -0.587308       -0.477051     -0.605849          0.0
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 5523          1.0             0.0               1.0
# 1676          0.0             0.0               1.0
# 511           0.0             0.0               1.0
# 1595          0.0             0.0               1.0
# 3329          1.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  ...  \
# 5523                             0.0                0.0  ...
# 1676                             0.0                1.0  ...
# ...

# %%
## Preparing Test Data

# %%
X_test.head()
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 942     Male              0      No         No      24          Yes
# 3730  Female              0     Yes         No      57          Yes
# 1761    Male              0      No         No      58          Yes
# 2283    Male              0      No         No       1          Yes
# 1872  Female              0     Yes        Yes      41          Yes
#
#      MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 942             No     Fiber optic                   No                   No
# 3730           Yes     Fiber optic                   No                  Yes
# 1761           Yes              No  No internet service  No internet service
# 2283            No     Fiber optic                   No                   No
# 1872            No              No  No internet service  No internet service
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1758 entries, 942 to 1506
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            1758 non-null   object
#  1   SeniorCitizen     1758 non-null   int64
#  2   Partner           1758 non-null   object
#  3   Dependents        1758 non-null   object
#  4   tenure            1758 non-null   int64
#  5   PhoneService      1758 non-null   object
#  6   MultipleLines     1758 non-null   object
#  7   InternetService   1758 non-null   object
#  8   OnlineSecurity    1758 non-null   object
#  9   OnlineBackup      1758 non-null   object
#  10  DeviceProtection  1758 non-null   object
#  11  TechSupport       1758 non-null   object
#  12  StreamingTV       1758 non-null   object
#  13  StreamingMovies   1758 non-null   object
#  14  Contract          1758 non-null   object
#  15  PaperlessBilling  1758 non-null   object
# ...

# %%
#### Separating Categorical and Numerical Columns:

# %%
X_test_cat = X_test.select_dtypes(include=['object'])

X_test_cat.head()
# Out:
#       gender Partner Dependents PhoneService MultipleLines InternetService  \
# 942     Male      No         No          Yes            No     Fiber optic
# 3730  Female     Yes         No          Yes           Yes     Fiber optic
# 1761    Male      No         No          Yes           Yes              No
# 2283    Male      No         No          Yes            No     Fiber optic
# 1872  Female     Yes        Yes          Yes            No              No
#
#            OnlineSecurity         OnlineBackup     DeviceProtection  \
# 942                    No                   No                   No
# 3730                   No                  Yes                  Yes
# 1761  No internet service  No internet service  No internet service
# 2283                   No                   No                   No
# 1872  No internet service  No internet service  No internet service
#
#               TechSupport          StreamingTV      StreamingMovies  \
# ...

# %%
X_test_num = X_test.select_dtypes(include=['int64', 'float64'])

X_test_num.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 942               0      24           79.85       2001.00
# 3730              0      57          104.50       5921.35
# 1761              0      58           24.45       1513.60
# 2283              0       1           71.55         71.55
# 1872              0      41           19.70        804.25

# %%
#### Scaling the Test Numerical Features

# %%
X_test_num_rescaled = pd.DataFrame(scaler.transform(X_test_num),
                                   columns = X_test_num.columns,
                                   index = X_test_num.index)

X_test_num_rescaled.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# 942       -0.438945 -0.342758        0.505026     -0.124435
# 3730      -0.438945  1.002262        1.324255      1.603476
# 1761      -0.438945  1.043021       -1.336161     -0.339259
# 2283      -0.438945 -1.280197        0.229180     -0.974849
# 1872      -0.438945  0.350131       -1.494025     -0.651908

# %%
X_test_cat_le = pd.DataFrame(index = X_test_cat.index)

X_test_cat_le.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [942, 3730, 1761, 2283, 1872]

# %%
#### Applying OneHotEncoding on Categorical Columns

# %%
X_test_cat_ohe = pd.DataFrame(encoder.transform(X_test_cat),
                               columns=encoder.get_feature_names_out(X_test_cat.columns),
                               index = X_test_cat.index)

X_test_cat_ohe.head()
# Out:
#       gender_Male  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 942           1.0          0.0             0.0               1.0
# 3730          0.0          1.0             0.0               1.0
# 1761          1.0          0.0             0.0               1.0
# 2283          1.0          0.0             0.0               1.0
# 1872          0.0          1.0             1.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  \
# 942                              0.0                0.0
# 3730                             0.0                1.0
# 1761                             0.0                1.0
# 2283                             0.0                0.0
# 1872                             0.0                0.0
#
#       InternetService_Fiber optic  InternetService_No  \
# 942                           1.0                 0.0
# 3730                          1.0                 0.0
# 1761                          0.0                 1.0
# ...

# %%
#### Concatinating the Encoded Categorical Features and Rescaled Numerical Features:

# %%
X_test_transformed = pd.concat([X_test_num_rescaled, X_test_cat_ohe], axis=1)

X_test_transformed.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 942       -0.438945 -0.342758        0.505026     -0.124435          1.0
# 3730      -0.438945  1.002262        1.324255      1.603476          0.0
# 1761      -0.438945  1.043021       -1.336161     -0.339259          1.0
# 2283      -0.438945 -1.280197        0.229180     -0.974849          1.0
# 1872      -0.438945  0.350131       -1.494025     -0.651908          0.0
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 942           0.0             0.0               1.0
# 3730          1.0             0.0               1.0
# 1761          0.0             0.0               1.0
# 2283          0.0             0.0               1.0
# 1872          1.0             1.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  ...  \
# 942                              0.0                0.0  ...
# 3730                             0.0                1.0  ...
# ...

# %%
## Model Building

# %%
### Logistic Regression

# %%
from sklearn import metrics

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train_transformed, y_train)
# Out:
# LogisticRegression()

# %%
### Prediction

# %%
y_test_pred = classifier.predict(X_test_transformed)

# %%
### Evaluation

# %%
metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.7957906712172924

# %%
sns.histplot(y_test, color='blue', alpha=0.5)
sns.histplot(y_test_pred, color='red', alpha=0.5)
# Out:
# <Axes: xlabel='Churn', ylabel='Count'>

# %%
### KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.757679180887372

# %%
sns.histplot(y_test, color='blue', alpha=0.5)
sns.histplot(y_test_pred, color='red', alpha=0.5)
# Out:
# <Axes: xlabel='Churn', ylabel='Count'>

# %%
### Decision Tree Classifier

# %%
sns.histplot(y_test, color='blue', alpha=0.5)
sns.histplot(y_test_pred, color='red', alpha=0.5)
# Out:
# <Axes: xlabel='Churn', ylabel='Count'>

# %%
### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.7229806598407281

# %%
sns.histplot(y_test, color='blue', alpha=0.5)
sns.histplot(y_test_pred, color='red', alpha=0.5)
# Out:
# <Axes: xlabel='Churn', ylabel='Count'>

# %%
### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.7787258248009101

# %%
sns.histplot(y_test, color='blue', alpha=0.5)
sns.histplot(y_test_pred, color='red', alpha=0.5)
# Out:
# <Axes: xlabel='Churn', ylabel='Count'>

# %%
### Support Vector Machine(SVC)

# %%
from sklearn.svm import SVC
classifier = SVC()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.78839590443686

# %%
sns.histplot(y_test, color='yellow', alpha=0.5)
sns.histplot(y_test_pred, color='green', alpha=0.5)
# Out:
# <Axes: xlabel='Churn', ylabel='Count'>

# %% [markdown]
# ## Conclusion

# %% [markdown]
# #### From the above Algorithms Logistic Regression, Random Forest Classifier and Spport Vector Classification accuracy is almost same then compare to KNN Classification and Decision Tree Classifier Algorithms accuracy is almost same.
